# %%
#import stuff
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

# %%
#read csv
df = pd.read_csv("iris.csv")
df
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.cluster import KMeans
predict = KMeans(n_clusters = 3, random_state = 0, n_init = "auto").fit(df[['sepallength', 'sepalwidth', 'petallength', 'petalwidth']])

# %%
predict.get_feature_names_out()
# Out:
# array(['kmeans0', 'kmeans1', 'kmeans2'], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
fig, axs = plt.subplots(figsize=(12, 12))
axs.scatter(df['petallength'], df['petalwidth'], c=predict.labels_)
plt.show()

# %%
fig, axs = plt.subplots(figsize=(12, 12))
axs.scatter(df['sepallength'], df['sepalwidth'], c=predict.labels_)
plt.show()

# %%
from sklearn.metrics import jaccard_score
from sklearn.metrics import rand_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score




# Assuming df is your feature matrix
labels = predict.labels_

rand = rand_score(df['class'], labels)
print(f"Rand Score: {rand}")


calins = calinski_harabasz_score(df[['sepallength', 'sepalwidth', 'petallength', 'petalwidth']], labels)
print(f"Calinski & Harabasz Score: {calins}")


silhouette = silhouette_score(df[['sepallength', 'sepalwidth', 'petallength', 'petalwidth']], labels)
print(f"Silhouette Score: {silhouette}")


davies = davies_bouldin_score(df[['sepallength', 'sepalwidth', 'petallength', 'petalwidth']], labels)
print(f"Davies Bouldin Index: {davies}")
# Out:
# Rand Score: 0.8737360178970918
# Calinski & Harabasz Score: 560.3660038653594
# Silhouette Score: 0.5509643746707443
# Davies Bouldin Index: 0.6663912107101494

# %%
from sklearn.cluster import SpectralClustering
predict = SpectralClustering(n_clusters=2, assign_labels='discretize', random_state=0).fit(df[['sepallength', 'sepalwidth', 'petallength', 'petalwidth']])

# %%
fig, axs = plt.subplots(figsize=(12, 12))
axs.scatter(df['petallength'], df['petalwidth'], c=predict.labels_)
plt.show()

# %%
fig, axs = plt.subplots(figsize=(12, 12))
axs.scatter(df['sepallength'], df['sepalwidth'], c=predict.labels_)
plt.show()

# %%
from sklearn.metrics import jaccard_score
from sklearn.metrics import rand_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score




# Assuming df is your feature matrix
labels = predict.labels_

rand = rand_score(df['class'], labels)
print(f"Rand Score: {rand}")


calins = calinski_harabasz_score(df[['sepallength', 'sepalwidth', 'petallength', 'petalwidth']], labels)
print(f"Calinski & Harabasz Score: {calins}")


silhouette = silhouette_score(df[['sepallength', 'sepalwidth', 'petallength', 'petalwidth']], labels)
print(f"Silhouette Score: {silhouette}")


davies = davies_bouldin_score(df[['sepallength', 'sepalwidth', 'petallength', 'petalwidth']], labels)
print(f"Davies Bouldin Index: {davies}")
# Out:
# Rand Score: 0.7762863534675615
# Calinski & Harabasz Score: 501.9248640964316
# Silhouette Score: 0.6863930543445408
# Davies Bouldin Index: 0.3835952094491397

# %%
from sklearn.cluster import Birch
predict = Birch(n_clusters=None).fit(df[['sepallength', 'sepalwidth', 'petallength', 'petalwidth']])

# %%
fig, axs = plt.subplots(figsize=(12, 12))
axs.scatter(df['petallength'], df['petalwidth'], c=predict.labels_)
plt.show()

# %%
fig, axs = plt.subplots(figsize=(12, 12))
axs.scatter(df['sepallength'], df['sepalwidth'], c=predict.labels_)
plt.show()

# %%
from sklearn.metrics import jaccard_score
from sklearn.metrics import rand_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score




# Assuming df is your feature matrix
labels = predict.labels_

rand = rand_score(df['class'], labels)
print(f"Rand Score: {rand}")


calins = calinski_harabasz_score(df[['sepallength', 'sepalwidth', 'petallength', 'petalwidth']], labels)
print(f"Calinski & Harabasz Score: {calins}")


silhouette = silhouette_score(df[['sepallength', 'sepalwidth', 'petallength', 'petalwidth']], labels)
print(f"Silhouette Score: {silhouette}")


davies = davies_bouldin_score(df[['sepallength', 'sepalwidth', 'petallength', 'petalwidth']], labels)
print(f"Davies Bouldin Index: {davies}")
# Out:
# Rand Score: 0.7707382550335571
# Calinski & Harabasz Score: 315.92474633833797
# Silhouette Score: 0.2932512902587518
# Davies Bouldin Index: 1.109073929929158

# %%
from sklearn.cluster import HDBSCAN
predict = HDBSCAN(min_cluster_size=20).fit(df[['sepallength', 'sepalwidth', 'petallength', 'petalwidth']])

# %%
fig, axs = plt.subplots(figsize=(12, 12))
axs.scatter(df['petallength'], df['petalwidth'], c=predict.labels_)
plt.show()

# %%
fig, axs = plt.subplots(figsize=(12, 12))
axs.scatter(df['sepallength'], df['sepalwidth'], c=predict.labels_)
plt.show()

# %%
from sklearn.metrics import jaccard_score
from sklearn.metrics import rand_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score




# Assuming df is your feature matrix
labels = predict.labels_

rand = rand_score(df['class'], labels)
print(f"Rand Score: {rand}")


calins = calinski_harabasz_score(df[['sepallength', 'sepalwidth', 'petallength', 'petalwidth']], labels)
print(f"Calinski & Harabasz Score: {calins}")


silhouette = silhouette_score(df[['sepallength', 'sepalwidth', 'petallength', 'petalwidth']], labels)
print(f"Silhouette Score: {silhouette}")


davies = davies_bouldin_score(df[['sepallength', 'sepalwidth', 'petallength', 'petalwidth']], labels)
print(f"Davies Bouldin Index: {davies}")
# Out:
# Rand Score: 0.7770917225950783
# Calinski & Harabasz Score: 292.18691847385196
# Silhouette Score: 0.5220343918107696
# Davies Bouldin Index: 0.5482993821202372
